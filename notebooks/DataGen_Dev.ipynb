# %%
import os
os.chdir('..')

import tensorflow as tf
import keras
import matplotlib.image as im
import matplotlib.pyplot as plt
import os
import megatron
from IPython.display import Image
from lib.Generator import DataGenerator
# Out:
# /home/matt/tools/miniconda3/envs/kaggle-hp/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/matt/tools/miniconda3/envs/kaggle-hp/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Using TensorFlow backend.

# %%
DATA_DIR = 'data'
TRAIN_DIR = DATA_DIR + '/train'
TEST_DIR = DATA_DIR + '/test'

# %%
file_
generator = DataGenerator(TRAIN_DIR, 32)

# %%
images = next(generator)

# %%
DIR = '/home/matt/Projects/kaggle/human-protein-atlas-image-classification/data/kaggle-train'
files = os.listdir(DIR)

# %%
unique_ids = list(
                set([file.split('_')[0] for file in os.listdir(DIR)])
            )

# %%
unique_ids
# Out:
# ['2753d3c8-bbbb-11e8-b2ba-ac1f6b6435d0',
#  '36a2025c-bbaf-11e8-b2ba-ac1f6b6435d0',
#  '5c82bdec-bbbc-11e8-b2ba-ac1f6b6435d0',
#  '3951542c-bbc2-11e8-b2bb-ac1f6b6435d0',
#  '0f91c2ce-bb9b-11e8-b2b9-ac1f6b6435d0',
#  '008a8630-bb9b-11e8-b2b9-ac1f6b6435d0',
#  'fd6e0e74-bba2-11e8-b2b9-ac1f6b6435d0',
#  '2611518c-bb9a-11e8-b2b9-ac1f6b6435d0',
#  '609819d0-bbb3-11e8-b2ba-ac1f6b6435d0',
#  'fb8b2a22-bbb3-11e8-b2ba-ac1f6b6435d0',
#  'ee3ee170-bb99-11e8-b2b9-ac1f6b6435d0',
#  'b2355c84-bbaa-11e8-b2ba-ac1f6b6435d0',
#  '362b2420-bbaa-11e8-b2ba-ac1f6b6435d0',
#  '659d06ee-bba8-11e8-b2ba-ac1f6b6435d0',
#  'd454945c-bbbd-11e8-b2ba-ac1f6b6435d0',
#  '3e1c1592-bb9e-11e8-b2b9-ac1f6b6435d0',
#  'dac86020-bbb8-11e8-b2ba-ac1f6b6435d0',
#  '5eb6298c-bb9e-11e8-b2b9-ac1f6b6435d0',
#  'ad2797e8-bbbe-11e8-b2ba-ac1f6b6435d0',
#  'a3d43a88-bba6-11e8-b2ba-ac1f6b6435d0',
#  'bdc6eb44-bbc8-11e8-b2bc-ac1f6b6435d0',
#  'b14731f4-bb9f-11e8-b2b9-ac1f6b6435d0',
#  '121e2430-bbc1-11e8-b2bb-ac1f6b6435d0',
# ...

# %%
def split_data():
